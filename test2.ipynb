# %%
# %matplotlib widget

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Test plot a function
#
# Plot the function $y = x^2+x+1$. for $x\in [0,10]$.

# %%
x = np.linspace(0,10,100)
y =  x**2+x+1
plt.figure()
plt.plot(x,y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
